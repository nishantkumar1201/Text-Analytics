# %%
import PyPDF2

# %%
f=open('Introduction_to_political_theory_(_PDFDrive_).pdf','rb')

# %%
f
# Out:
# <_io.BufferedReader name='Introduction_to_political_theory_(_PDFDrive_).pdf'>

# %%
pdf_reader=PyPDF2.PdfReader(f)

# %%
pdf_reader

# %%
len(pdf_reader.pages)
# Out:
# 591

# %%
page_one=pdf_reader.pages[0]

# %%
page_one
# Out:
# {'/Annots': [],
#  '/Contents': [IndirectObject(6, 0, 3015684803600),
#   IndirectObject(7, 0, 3015684803600),
#   IndirectObject(8, 0, 3015684803600),
#   IndirectObject(9, 0, 3015684803600)],
#  '/Group': {'/CS': '/DeviceRGB', '/I': True, '/S': '/Transparency'},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Resources': {'/ExtGState': {'/FXE1': {'/AIS': False,
#     '/BM': '/Normal',
#     '/TR': '/Identity',
#     '/ca': 1,
#     '/CA': 1,
#     '/SMask': '/None'},
#    '/FXE2': {'/AIS': False,
#     '/BM': '/Normal',
#     '/TR': '/Identity',
#     '/ca': 0.5,
#     '/CA': 0.5,
#     '/SMask': '/None'}},
#   '/Font': {'/F6': {'/BaseFont': '/GAAAAA+LiberationSans-Italic',
#     '/ToUnicode': {'/Filter': '/FlateDecode'},
#     '/FirstChar': 0,
#     '/Subtype': '/TrueType',
#     '/Type': '/Font',
#     '/LastChar': 68,
#     '/Widths': [365,
#      722,
#      556,
#      556,
#      277,
#      556,
#      500,
#      777,
#      722,
#      556,
#      722,
#      666,
#      277,
# ...

# %%
page_one_text=page_one.extract_text()

# %%
page_one_text
# Out:
# 'An Introduction \nto\nPolitical\nTheory\nFIFTH EDITION\nO.P. Gauba\nFormerly, Reader in Political Science\nCampus of Open Learning\nUniversity of Delhi\nMACMILLAN\nhttps://telegram.me/UPSCMaterials\nhttps://telegram.me/FreeUPSCMaterials\nhttps://telegram.me/MaterialforExam\n'

# %%
f=open("poli","rb") f=open('US_Declaration (1).pdf','rb')

# %%
pdf_writer=PyPDF2.PdfWriter(f)

# %%
first_page=page=pdf_reader.pages[0]

# %%
pdf_writer.add_page(first_page)
# Out:
# {'/Annots': [],
#  '/Contents': [IndirectObject(6, 0, 1997896634320),
#   IndirectObject(7, 0, 1997896634320),
#   IndirectObject(8, 0, 1997896634320),
#   IndirectObject(9, 0, 1997896634320)],
#  '/Group': {'/CS': '/DeviceRGB', '/I': True, '/S': '/Transparency'},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Resources': {'/ExtGState': {'/FXE1': {'/AIS': False,
#     '/BM': '/Normal',
#     '/TR': '/Identity',
#     '/ca': 1,
#     '/CA': 1,
#     '/SMask': '/None'},
#    '/FXE2': {'/AIS': False,
#     '/BM': '/Normal',
#     '/TR': '/Identity',
#     '/ca': 0.5,
#     '/CA': 0.5,
#     '/SMask': '/None'}},
#   '/Font': {'/F6': {'/BaseFont': '/GAAAAA+LiberationSans-Italic',
#     '/ToUnicode': {'/Filter': '/FlateDecode'},
#     '/FirstChar': 0,
#     '/Subtype': '/TrueType',
#     '/Type': '/Font',
#     '/LastChar': 68,
#     '/Widths': [365,
#      722,
#      556,
#      556,
#      277,
#      556,
#      500,
#      777,
#      722,
#      556,
#      722,
#      666,
#      277,
# ...

# %%
pdf_writer.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='New_Doc.pdf'>)

# %%
first_page=pdf_reader.pages[0]

# %%
first_page
# Out:
# {'/Annots': [],
#  '/Contents': [IndirectObject(1974, 0, 1997887612688),
#   IndirectObject(2, 0, 1997887612688),
#   IndirectObject(1975, 0, 1997887612688),
#   IndirectObject(1973, 0, 1997887612688)],
#  '/Group': {'/CS': '/DeviceRGB', '/I': True, '/S': '/Transparency'},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Parent': {'/Resources': {'/ExtGState': {'/FXE1': {'/AIS': False,
#      '/BM': '/Normal',
#      '/TR': '/Identity',
#      '/ca': 1,
#      '/CA': 1,
#      '/SMask': '/None'},
#     '/FXE2': {'/AIS': False,
#      '/BM': '/Normal',
#      '/TR': '/Identity',
#      '/ca': 0.5,
#      '/CA': 0.5,
#      '/SMask': '/None'}},
#    '/Font': {'/F6': {'/BaseFont': '/GAAAAA+LiberationSans-Italic',
#      '/ToUnicode': {'/Filter': '/FlateDecode'},
#      '/FirstChar': 0,
#      '/Subtype': '/TrueType',
#      '/Type': '/Font',
#      '/LastChar': 68,
#      '/Widths': [365,
#       722,
#       556,
#       556,
#       277,
#       556,
#       500,
#       777,
#       722,
# ...

# %%
page_one_text=page_one.extract_text()

# %%
page_one_text
# Out:
# 'An Introduction \nto\nPolitical\nTheory\nFIFTH EDITION\nO.P. Gauba\nFormerly, Reader in Political Science\nCampus of Open Learning\nUniversity of Delhi\nMACMILLAN\nhttps://telegram.me/UPSCMaterials\nhttps://telegram.me/FreeUPSCMaterials\nhttps://telegram.me/MaterialforExam\n'

# %%
f=open('Introduction_to_political_theory_(_PDFDrive_).pdf','rb')

# %%
pdf_reader=PyPDF2.PdfReader(f)

# %%
first_page=page=pdf_reader.pages[0]

# %%
pdf_writer=PyPDF2.PdfWriter(f)

# %%
pdf_writer.add_page(first_page)
# Out:
# {'/Annots': [],
#  '/Contents': [IndirectObject(6, 0, 3015683472720),
#   IndirectObject(7, 0, 3015683472720),
#   IndirectObject(8, 0, 3015683472720),
#   IndirectObject(9, 0, 3015683472720)],
#  '/Group': {'/CS': '/DeviceRGB', '/I': True, '/S': '/Transparency'},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Resources': {'/ExtGState': {'/FXE1': {'/AIS': False,
#     '/BM': '/Normal',
#     '/TR': '/Identity',
#     '/ca': 1,
#     '/CA': 1,
#     '/SMask': '/None'},
#    '/FXE2': {'/AIS': False,
#     '/BM': '/Normal',
#     '/TR': '/Identity',
#     '/ca': 0.5,
#     '/CA': 0.5,
#     '/SMask': '/None'}},
#   '/Font': {'/F6': {'/BaseFont': '/GAAAAA+LiberationSans-Italic',
#     '/ToUnicode': {'/Filter': '/FlateDecode'},
#     '/FirstChar': 0,
#     '/Subtype': '/TrueType',
#     '/Type': '/Font',
#     '/LastChar': 68,
#     '/Widths': [365,
#      722,
#      556,
#      556,
#      277,
#      556,
#      500,
#      777,
#      722,
#      556,
#      722,
#      666,
#      277,
# ...

# %%
pdf_output=open("New_Doc.pdf","wb")

# %%
pdf_writer.write(pdf_output)
# Out:
# (False, <_io.BufferedWriter name='New_Doc.pdf'>)

# %%
pdf_output.close()
f.close()

# %%
f=open('New_Doc.pdf','rb')

# %%
pdf_reader=PyPDF2.PdfReader(f)

# %%
len(pdf_reader.pages)
# Out:
# 1

# %%
page_one=pdf_reader.pages[0]

# %%
page_one_text=page_one.extract_text()

# %%
page_one_text
# Out:
# 'An Introduction \nto\nPolitical\nTheory\nFIFTH EDITION\nO.P. Gauba\nFormerly, Reader in Political Science\nCampus of Open Learning\nUniversity of Delhi\nMACMILLAN\nhttps://telegram.me/UPSCMaterials\nhttps://telegram.me/FreeUPSCMaterials\nhttps://telegram.me/MaterialforExam\n'

# %%
f=open("US_Declaration (1).pdf",'rb')

# %%
f
# Out:
# <_io.BufferedReader name='US_Declaration (1).pdf'>

# %%
pdf_text=[]
for p in range(len(pdf_reader.pages)):
    page=pdf_reader.pages[p]
    pdf_text.append(page.extract_text())
f.close()
